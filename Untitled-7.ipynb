# %%
import random
import numpy as np
import time 

arrival = []
serve = []
departure = []

def sim_witout_priority(env, name, sellers):

    print(f"Customer {name} joins queue at  {env.now:.2f}")
    arrival.append((name , f'{env.now:.2f}' ))
    with sellers.request() as request:
        yield request
    
        
        print(f"Customer {name} starts being served by a seller {salesperson} at time {env.now:.2f}")

        salesperson = sellers.users.index(request) + 1

        serve.append((name, f'{env.now:.2f}',f"salesperson: {salesperson}"))
        support_time = max(np.random.normal(10, 4), 1) #using max to prevent negative delay
        yield env.timeout(support_time)
        
        print(f'Customer {name} finishes being served by a seller {salesperson} at time {env.now:.2f}, seller spend {support_time:.2f} for customer {name}')
        departure.append((name, f'{env.now:.2f}'))
def generate_customers_without_pri(env, sellers , max_customers):
    customer_num = 0
    while customer_num < max_customers:
        customer_num += 1
        env.process(sim_witout_priority(env, customer_num, sellers))
        enter_queue_time = random.expovariate(0.13)  #beccause customers enter shop in random time
        yield env.timeout(enter_queue_time)


def sim_with_priority(env, name, sellers, priority_customers):
 
    print(f"Customer {name} joins queue at time {env.now:.2f}")

    if name in priority_customers:
        with sellers.request() as request:
            yield request

            print(f"Priority customer {name} starts being served by a seller at time {env.now:.2f}")

            support_time = max(np.random.normal(10, 4), 1)
            yield env.timeout(support_time)

            print(f"Priority customer {name} finishes being served by a seller at time {env.now:.2f}, seller spend {support_time:.2f} for customer {name}")
    else:
        with sellers.request(priority=1) as request:
            yield request

            print(f"Customer {name} starts being served by a seller at time {env.now:.2f}")

            support_time = max(np.random.normal(10, 4), 1)
            yield env.timeout(support_time)

            print(f"Customer {name} finishes being served by a seller at time {env.now:.2f}, seller spend {support_time:.2f} for customer {name}")

def generate_customers_with_pri(env, sellers, priority_customers, max_customers):
    customer_num = 0
    while customer_num < max_customers:
        customer_num += 1
        env.process(sim_with_priority(env, customer_num, sellers, priority_customers))
        enter_queue_time = random.expovariate(0.13)  
        yield env.timeout(enter_queue_time)

# %%
import random
import simpy

MAX_CUSTOMERS = 30
NUM_SELLERS = 2  
NUM_PRIORITY_CUSTOMERS = 10
MAXIMUM_TIME = 200

running_code = True


def setup_without_pri():
    print("\nCandy Shop simulation with priority customers start \n")
    env = simpy.Environment()
    sellers = simpy.Resource(env, capacity= NUM_SELLERS)
    env.process(generate_customers_without_pri(env, sellers , MAX_CUSTOMERS))
    env.run(until= MAXIMUM_TIME) 
    print("\nCandy Shop simulation without priority customers ended \n")

    
def setup_with_pri():
    print("\nCandy Shop simulation with priority customers start \n")
    env = simpy.Environment()
    sellers = simpy.PriorityResource(env, capacity= NUM_SELLERS)
    priority_customers = random.sample(range(1, MAX_CUSTOMERS + 1), NUM_PRIORITY_CUSTOMERS)
    env.process(generate_customers_with_pri(env, sellers, priority_customers, MAX_CUSTOMERS))
    env.run(until= MAXIMUM_TIME)
    print("\nCandy Shop simulation with priority customers ended \n")

# %%
setup_without_pri()
# Out:
# Candy Shop simulation with priority customers start
#
# Customer 1 joins queue at  0.00
# Customer 1 starts being served by a seller at time 0.00
# Customer 2 joins queue at  5.87
# Customer 2 starts being served by a seller at time 5.87
# Customer 3 joins queue at  16.59
# Customer 2 finishes being served by a seller 2 at time 16.97, seller spend 11.10 for customer 2
# Customer 3 starts being served by a seller at time 16.97
# Customer 1 finishes being served by a seller 1 at time 20.41, seller spend 20.41 for customer 1
# Customer 3 finishes being served by a seller 2 at time 21.50, seller spend 4.53 for customer 3
# Customer 4 joins queue at  32.99
# Customer 4 starts being served by a seller at time 32.99
# Customer 5 joins queue at  33.23
# Customer 5 starts being served by a seller at time 33.23
# Customer 6 joins queue at  33.72
# Customer 5 finishes being served by a seller 2 at time 41.85, seller spend 8.62 for customer 5
# Customer 6 starts being served by a seller at time 41.85
# Customer 4 finishes being served by a seller 1 at time 42.85, seller spend 9.87 for customer 4
# Customer 7 joins queue at  54.51
# Customer 7 starts being served by a seller at time 54.51
# Customer 6 finishes being served by a seller 2 at time 55.39, seller spend 13.54 for customer 6
# Customer 7 finishes being served by a seller 2 at time 61.51, seller spend 7.01 for customer 7
# Customer 8 joins queue at  63.80
# Customer 8 starts being served by a seller at time 63.80
# Customer 9 joins queue at  66.10
# Customer 9 starts being served by a seller at time 66.10
# Customer 8 finishes being served by a seller 1 at time 73.51, seller spend 9.71 for customer 8
# Customer 10 joins queue at  76.97
# Customer 10 starts being served by a seller at time 76.97
# Customer 10 finishes being served by a seller 2 at time 77.97, seller spend 1.00 for customer 10
# Customer 9 finishes being served by a seller 2 at time 86.64, seller spend 20.54 for customer 9
# Customer 11 joins queue at  101.63
# Customer 11 starts being served by a seller at time 101.63
# Customer 11 finishes being served by a seller 1 at time 112.31, seller spend 10.68 for customer 11
# Customer 12 joins queue at  113.32
# Customer 12 starts being served by a seller at time 113.32
# Customer 13 joins queue at  123.81
# Customer 13 starts being served by a seller at time 123.81
# Customer 12 finishes being served by a seller 1 at time 128.15, seller spend 14.83 for customer 12
# Customer 13 finishes being served by a seller 2 at time 131.40, seller spend 7.59 for customer 13
# Customer 14 joins queue at  132.19
# Customer 14 starts being served by a seller at time 132.19
# Customer 14 finishes being served by a seller 1 at time 140.01, seller spend 7.82 for customer 14
# Customer 15 joins queue at  140.72
# Customer 15 starts being served by a seller at time 140.72
# Customer 16 joins queue at  142.30
# Customer 16 starts being served by a seller at time 142.30
# Customer 17 joins queue at  148.99
# Customer 16 finishes being served by a seller 2 at time 150.91, seller spend 8.61 for customer 16
# Customer 17 starts being served by a seller at time 150.91
# Customer 18 joins queue at  152.44
# Customer 19 joins queue at  152.49
# Customer 20 joins queue at  153.30
# Customer 15 finishes being served by a seller 1 at time 155.23, seller spend 14.50 for customer 15
# Customer 18 starts being served by a seller at time 155.23
# Customer 17 finishes being served by a seller 2 at time 162.85, seller spend 11.94 for customer 17
# Customer 19 starts being served by a seller at time 162.85
# Customer 18 finishes being served by a seller 2 at time 171.70, seller spend 16.47 for customer 18
# Customer 20 starts being served by a seller at time 171.70
# Customer 21 joins queue at  174.72
# Customer 20 finishes being served by a seller 2 at time 175.42, seller spend 3.72 for customer 20
# Customer 21 starts being served by a seller at time 175.42
# Customer 22 joins queue at  176.62
# Customer 19 finishes being served by a seller 2 at time 177.06, seller spend 14.22 for customer 19
# Customer 22 starts being served by a seller at time 177.06
# Customer 23 joins queue at  177.92
# Customer 21 finishes being served by a seller 2 at time 184.61, seller spend 9.19 for customer 21
# Customer 23 starts being served by a seller at time 184.61
# Customer 24 joins queue at  189.20
# Customer 25 joins queue at  190.90
# Customer 26 joins queue at  191.60
# Customer 22 finishes being served by a seller 2 at time 191.64, seller spend 14.57 for customer 22
# Customer 24 starts being served by a seller at time 191.64
# Customer 23 finishes being served by a seller 2 at time 194.61, seller spend 9.99 for customer 23
# Customer 25 starts being served by a seller at time 194.61
#
# Candy Shop simulation without priority customers ended

# %%
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
